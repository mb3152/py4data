# %% [markdown]
# #### Part 1: Create a table of the 50 most travelled airports in the US containing relevant information such as name, city, ICAO airport code, latitude, and longitude.

# %%
import pandas as pd
import numpy as np
import time
from pandas.io import sql
import ast
import sqlite3

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### I did a bit first in pandas

# %%
#get the top airports
topair= pd.read_csv('top_airports.csv')

# %%
#get the data on all airports
airdata = pd.read_csv('ICAO_airports.csv')

# %%
#merge them, leaving on the data on the top 50 airports.
#I know you can do this in the database, but pandas makes it too easy to do beforehand.
airdata.rename(columns={'iata_code': 'IATA'}, inplace=True)
airdata = pd.merge(topair, airdata, on='IATA')

# %%
airdata
# Out:
#                                     City  FAA IATA  ICAO  \
# 0                                Atlanta  ATL  ATL  KATL
# 1                                Chicago  ORD  ORD  KORD
# 2                            Los Angeles  LAX  LAX  KLAX
# 3                      Dallas-Fort Worth  DFW  DFW  KDFW
# 4                                 Denver  DEN  DEN  KDEN
# 5                               New York  JFK  JFK  KJFK
# 6                          San Francisco  SFO  SFO  KSFO
# 7                                Houston  IAH  IAH  KIAH
# 8                              Las Vegas  LAS  LAS  KLAS
# 9                                Phoenix  PHX  PHX  KPHX
# 10                             Charlotte  CLT  CLT  KCLT
# 11                                 Miami  MIA  MIA  KMIA
# 12                               Orlando  MCO  MCO  KMCO
# 13                                Newark  EWR  EWR  KEWR
# 14                     Detroit / Romulus  DTW  DTW  KDTW
# 15                           Minneapolis  MSP  MSP  KMSP
# 16             Seattle / Tacoma (SeaTac)  SEA  SEA  KSEA
# 17                          Philadelphia  PHL  PHL  KPHL
# 18                                Boston  BOS  BOS  KBOS
# 19                              New York  LGA  LGA  KLGA
# 20  Washington D.C. / Chantilly / Dulles  IAD  IAD  KIAD
# 21               Baltimore / Glen Burnie  BWI  BWI  KBWI
# 22                       Fort Lauderdale  FLL  FLL  KFLL
# 23                        Salt Lake City  SLC  SLC  KSLC
# 24                              Honolulu  HNL  HNL  PHNL
# 25    Washington D.C. / Arlington County  DCA  DCA  KDCA
# 26                               Chicago  MDW  MDW  KMDW
# 27                             San Diego  SAN  SAN  KSAN
# 28                                 Tampa  TPA  TPA  KTPA
# 29                              Portland  PDX  PDX  KPDX
# 30                             St. Louis  STL  STL  KSTL
# 31                           Kansas City  MCI  MCI  KMCI
# 32                               Memphis  MEM  MEM  KMEM
# 33                             Cleveland  CLE  CLE  KCLE
# 34                               Oakland  OAK  OAK  KOAK
# 35                   San Juan / Carolina  SJU  SJU  TJSJ
# 36                               Raleigh  RDU  RDU  KRDU
# 37                             Nashville  BNA  BNA  KBNA
# 38                            Sacramento  SMF  SMF  KSMF
# 39                               Houston  HOU  HOU  KHOU
# 40                             Santa Ana  SNA  SNA  KSNA
# 41                                Austin  AUS  AUS  KAUS
# 42                              San Jose  SJC  SJC  KSJC
# 43                           New Orleans  MSY  MSY  KMSY
# 44                            Pittsburgh  PIT  PIT  KPIT
# 45                           San Antonio  SAT  SAT  KSAT
# 46                             Covington  CVG  CVG  KCVG
# 47                             Milwaukee  MKE  MKE  KMKE
# 48                                Dallas  DAL  DAL  KDAL
# 49                          Indianapolis  IND  IND  KIND
#
#                                               Airport Role  Enplanements  \
# 0    Hartsfield-Jackson Atlanta International Airport  P-L      43130585
# 1                Chicago O'Hare International Airport  P-L      32171831
# 2                   Los Angeles International Airport  P-L      30528737
# 3             Dallas/Fort Worth International Airport  P-L      27100656
# 4                        Denver International Airport  P-L      25241962
# 5               John F. Kennedy International Airport  P-L      22934047
# 6                 San Francisco International Airport  P-L      20038679
# 7                George Bush Intercontinental Airport  P-L      19528631
# 8                      McCarran International Airport  P-L      18996738
# 9            Phoenix Sky Harbor International Airport  P-L      18907171
# 10            Charlotte/Douglas International Airport  P-L      18629181
# 11                        Miami International Airport  P-L      17017654
# 12                      Orlando International Airport  P-L      17017491
# 13               Newark Liberty International Airport  P-L      16571754
# 14          Detroit Metropolitan Wayne County Airport  P-L      15643890
# 15  Minneapolis-St. Paul International Airport (Wo...  P-L      15512487
# 16               Seattle-Tacoma International Airport  P-L      15406243
# 17                 Philadelphia International Airport  P-L      14951254
# 18   Gen. Edward Lawrence Logan International Airport  P-L      13561814
# 19        LaGuardia Airport (and Marine Air Terminal)  P-L      12001501
# 20            Washington Dulles International Airport  P-L      11276481
# 21  Baltimore/Washington International Thurgood Ma...  P-L      10848633
# 22    Fort Lauderdale–Hollywood International Airport  P-L      10829810
# 23               Salt Lake City International Airport  P-L       9910493
# 24        Honolulu International Airport / Hickam AFB  P-L       8740077
# 25          Ronald Reagan Washington National Airport  P-L       8736804
# 26               Chicago Midway International Airport  P-L       8518957
# 27                    San Diego International Airport  P-L       8430509
# 28                        Tampa International Airport  P-L       8137222
# 29                     Portland International Airport  P-M       6582227
# 30            Lambert-St. Louis International Airport  P-M       6044760
# 31                  Kansas City International Airport  P-M       4946173
# 32                      Memphis International Airport  P-M       4930935
# 33            Cleveland-Hopkins International Airport  P-M       4704329
# 34                      Oakland International Airport  P-M       4673417
# 35             Luis Muñoz Marín International Airport  P-M       4635798
# 36               Raleigh-Durham International Airport  P-M       4465736
# 37      Nashville International Airport (Berry Field)  P-M       4432527
# 38                   Sacramento International Airport  P-M       4424279
# 39                           William P. Hobby Airport  P-M       4357835
# 40  John Wayne Airport – Orange County (was Orange...  P-M       4278623
# 41             Austin-Bergstrom International Airport  P-M       4201136
# 42    Norman Y. Mineta San José International Airport  P-M       4108167
# 43  Louis Armstrong New Orleans International Airport  P-M       4088889
# 44                   Pittsburgh International Airport  P-M       3996656
# 45                  San Antonio International Airport  P-M       3916320
# 46  Cincinnati/Northern Kentucky International Air...  P-M       3906826
# 47             General Mitchell International Airport  P-M       3861333
# 48                                  Dallas Love Field  P-M       3783407
# 49                 Indianapolis International Airport  P-M       3728698
#
#       id ident           type  \
# 0   3384  KATL  large_airport
# 1   3754  KORD  large_airport
# 2   3632  KLAX  large_airport
# 3   3488  KDFW  large_airport
# 4   3486  KDEN  large_airport
# 5   3622  KJFK  large_airport
# 6   3878  KSFO  large_airport
# 7   3604  KIAH  large_airport
# 8   3631  KLAS  large_airport
# 9   3772  KPHX  large_airport
# 10  3457  KCLT  large_airport
# 11  3685  KMIA  large_airport
# 12  3670  KMCO  large_airport
# 13  3521  KEWR  large_airport
# 14  3497  KDTW  large_airport
# 15  3709  KMSP  large_airport
# 16  3875  KSEA  large_airport
# 17  3771  KPHL  large_airport
# 18  3422  KBOS  large_airport
# 19  3643  KLGA  large_airport
# 20  3602  KIAD  large_airport
# 21  3435  KBWI  large_airport
# 22  3531  KFLL  large_airport
# 23  3887  KSLC  large_airport
# 24  5453  PHNL  large_airport
# 25  3483  KDCA  large_airport
# 26  3673  KMDW  large_airport
# 27  3862  KSAN  large_airport
# 28  3926  KTPA  large_airport
# 29  3768  KPDX  large_airport
# 30  3905  KSTL  large_airport
# 31  3668  KMCI  large_airport
# 32  3675  KMEM  large_airport
# 33  3454  KCLE  large_airport
# 34  3744  KOAK  large_airport
# 35  6384  TJSJ  large_airport
# 36  3844  KRDU  large_airport
# 37  3420  KBNA  large_airport
# 38  3892  KSMF  large_airport
# 39  3588  KHOU  large_airport
# 40  3894  KSNA  large_airport
# 41  3386  KAUS  large_airport
# 42  3883  KSJC  large_airport
# 43  3711  KMSY  large_airport
# 44  3778  KPIT  large_airport
# 45  3863  KSAT  large_airport
# 46  3471  KCVG  large_airport
# 47  3690  KMKE  large_airport
# 48  3479  KDAL  large_airport
# 49  3610  KIND  large_airport
#
#                                                  name  latitude_deg  \
# 0    Hartsfield Jackson Atlanta International Airport     33.636700
# 1                Chicago O'Hare International Airport     41.978600
# 2                   Los Angeles International Airport     33.942501
# 3             Dallas Fort Worth International Airport     32.896801
# 4                        Denver International Airport     39.861698
# 5                John F Kennedy International Airport     40.639801
# 6                 San Francisco International Airport     37.618999
# 7        George Bush Intercontinental Houston Airport     29.984400
# 8                      McCarran International Airport     36.080101
# 9            Phoenix Sky Harbor International Airport     33.434299
# 10            Charlotte Douglas International Airport     35.214001
# 11                        Miami International Airport     25.793200
# 12                      Orlando International Airport     28.429399
# 13               Newark Liberty International Airport     40.692501
# 14          Detroit Metropolitan Wayne County Airport     42.212399
# 15  Minneapolis-St Paul International/Wold-Chamber...     44.882000
# 16               Seattle Tacoma International Airport     47.449001
# 17                 Philadelphia International Airport     39.871899
# 18  General Edward Lawrence Logan International Ai...     42.364300
# 19                                 La Guardia Airport     40.777199
# 20            Washington Dulles International Airport     38.944500
# 21  Baltimore/Washington International Thurgood Ma...     39.175400
# 22    Fort Lauderdale Hollywood International Airport     26.072599
# 23               Salt Lake City International Airport     40.788399
# 24                     Honolulu International Airport     21.318701
# 25          Ronald Reagan Washington National Airport     38.852100
# 26               Chicago Midway International Airport     41.785999
# 27                    San Diego International Airport     32.733601
# 28                        Tampa International Airport     27.975500
# 29                     Portland International Airport     45.588699
# 30             Lambert St Louis International Airport     38.748699
# 31                  Kansas City International Airport     39.297600
# 32                      Memphis International Airport     35.042400
# 33            Cleveland Hopkins International Airport     41.411701
# 34         Metropolitan Oakland International Airport     37.721298
# 35             Luis Munoz Marin International Airport     18.439400
# 36               Raleigh Durham International Airport     35.877602
# 37                    Nashville International Airport     36.124500
# 38                   Sacramento International Airport     38.695400
# 39                            William P Hobby Airport     29.645399
# 40           John Wayne Airport-Orange County Airport     33.675701
# 41             Austin Bergstrom International Airport     30.194500
# 42    Norman Y. Mineta San Jose International Airport     37.362598
# 43  Louis Armstrong New Orleans International Airport     29.993401
# 44                   Pittsburgh International Airport     40.491501
# 45                  San Antonio International Airport     29.533701
# 46  Cincinnati Northern Kentucky International Air...     39.048801
# 47             General Mitchell International Airport     42.947201
# 48                                  Dallas Love Field     32.847099
# 49                 Indianapolis International Airport     39.717300
#
#     longitude_deg  elevation_ft continent iso_country iso_region  \
# 0      -84.428101          1026       NaN          US      US-GA
# 1      -87.904800           672       NaN          US      US-IL
# 2     -118.407997           125       NaN          US      US-CA
# 3      -97.038002           607       NaN          US      US-TX
# 4     -104.672997          5431       NaN          US      US-CO
# 5      -73.778900            13       NaN          US      US-NY
# 6     -122.375000            13       NaN          US      US-CA
# 7      -95.341400            97       NaN          US      US-TX
# 8     -115.152000          2181       NaN          US      US-NV
# 9     -112.012001          1135       NaN          US      US-AZ
# 10     -80.943100           748       NaN          US      US-NC
# 11     -80.290604             8       NaN          US      US-FL
# 12     -81.308998            96       NaN          US      US-FL
# 13     -74.168701            18       NaN          US      US-NJ
# 14     -83.353401           645       NaN          US      US-MI
# 15     -93.221802           841       NaN          US      US-MN
# 16    -122.308998           433       NaN          US      US-WA
# 17     -75.241096            36       NaN          US      US-PA
# 18     -71.005203            20       NaN          US      US-MA
# 19     -73.872597            21       NaN          US      US-NY
# 20     -77.455803           312       NaN          US      US-DC
# 21     -76.668297           146       NaN          US      US-MD
# 22     -80.152702             9       NaN          US      US-FL
# 23    -111.977997          4227       NaN          US      US-UT
# 24    -157.921997            13       NaN          US      US-HI
# 25     -77.037697            15       NaN          US      US-DC
# 26     -87.752403           620       NaN          US      US-IL
# 27    -117.190002            17       NaN          US      US-CA
# 28     -82.533203            26       NaN          US      US-FL
# 29    -122.598000            31       NaN          US      US-OR
# 30     -90.370003           618       NaN          US      US-MO
# 31     -94.713898          1026       NaN          US      US-MO
# 32     -89.976700           341       NaN          US      US-TN
# 33     -81.849800           791       NaN          US      US-OH
# 34    -122.221001             9       NaN          US      US-CA
# 35     -66.001801             9       NaN          PR     PR-U-A
# 36     -78.787498           435       NaN          US      US-NC
# 37     -86.678200           599       NaN          US      US-TN
# 38    -121.591003            27       NaN          US      US-CA
# 39     -95.278900            46       NaN          US      US-TX
# 40    -117.867996            56       NaN          US      US-CA
# 41     -97.669899           542       NaN          US      US-TX
# 42    -121.929001            62       NaN          US      US-CA
# 43     -90.258003             4       NaN          US      US-LA
# 44     -80.232903          1203       NaN          US      US-PA
# 45     -98.469803           809       NaN          US      US-TX
# 46     -84.667801           896       NaN          US      US-KY
# 47     -87.896599           723       NaN          US      US-WI
# 48     -96.851799           487       NaN          US      US-TX
# 49     -86.294403           797       NaN          US      US-IN
#
#          municipality scheduled_service gps_code local_code  \
# 0             Atlanta               yes     KATL        ATL
# 1             Chicago               yes     KORD        ORD
# 2         Los Angeles               yes     KLAX        LAX
# 3   Dallas-Fort Worth               yes     KDFW        DFW
# 4              Denver               yes     KDEN        DEN
# 5            New York               yes     KJFK        JFK
# 6       San Francisco               yes     KSFO        SFO
# 7             Houston               yes     KIAH        IAH
# 8           Las Vegas               yes     KLAS        LAS
# 9             Phoenix               yes     KPHX        PHX
# 10          Charlotte               yes     KCLT        CLT
# 11              Miami               yes     KMIA        MIA
# 12            Orlando               yes     KMCO        MCO
# 13             Newark               yes     KEWR        EWR
# 14            Detroit               yes     KDTW        DTW
# 15        Minneapolis               yes     KMSP        MSP
# 16            Seattle               yes     KSEA        SEA
# 17       Philadelphia               yes     KPHL        PHL
# 18             Boston               yes     KBOS        BOS
# 19           New York               yes     KLGA        LGA
# 20         Washington               yes     KIAD        IAD
# 21          Baltimore               yes     KBWI        BWI
# 22    Fort Lauderdale               yes     KFLL        FLL
# 23     Salt Lake City               yes     KSLC        SLC
# 24           Honolulu               yes     PHNL        HNL
# 25         Washington               yes     KDCA        DCA
# 26            Chicago               yes     KMDW        MDW
# 27          San Diego               yes     KSAN        SAN
# 28              Tampa               yes     KTPA        TPA
# 29           Portland               yes     KPDX        PDX
# 30           St Louis               yes     KSTL        STL
# 31        Kansas City               yes     KMCI        MCI
# 32            Memphis               yes     KMEM        MEM
# 33          Cleveland               yes     KCLE        CLE
# 34            Oakland               yes     KOAK        OAK
# 35           San Juan               yes     TJSJ        SJU
# 36     Raleigh/Durham               yes     KRDU        RDU
# 37          Nashville               yes     KBNA        BNA
# 38         Sacramento               yes     KSMF        SMF
# 39            Houston               yes     KHOU        HOU
# 40          Santa Ana               yes     KSNA        SNA
# 41             Austin               yes     KAUS        AUS
# 42           San Jose               yes     KSJC        SJC
# 43        New Orleans               yes     KMSY        MSY
# 44         Pittsburgh               yes     KPIT        PIT
# 45        San Antonio               yes     KSAT        SAT
# 46         Cincinnati               yes     KCVG        CVG
# 47          Milwaukee               yes     KMKE        MKE
# 48             Dallas               yes     KDAL        DAL
# 49       Indianapolis               yes     KIND        IND
#
#                                             home_link  \
# 0                     http://www.atlanta-airport.com/
# 1   http://www.flychicago.com/Ohare/OhareHomepage....
# 2                             http://www.iflylax.com/
# 3                          http://www.dfwairport.com/
# 4                           http://www.flydenver.com/
# 5   http://www.panynj.gov/CommutingTravel/airports...
# 6                              http://www.flysfo.com/
# 7                      http://www.fly2houston.com/iah
# 8                            http://www.mccarran.com/
# 9                http://phoenix.gov/skyharborairport/
# 10                   http://www.charlotteairport.com/
# 11                      http://www.miami-airport.com/
# 12                    http://www.orlandoairports.net/
# 13  http://www.panynj.gov/CommutingTravel/airports...
# 14                       http://www.metroairport.com/
# 15                         http://www.mspairport.com/
# 16                 http://www.portseattle.org/seatac/
# 17                                http://www.phl.org/
# 18                     http://www.massport.com/logan/
# 19  http://www.panynj.gov/CommutingTravel/airports...
# 20                        http://www.mwaa.com/dulles/
# 21                                                NaN
# 22                                http://www.fll.net/
# 23                                                NaN
# 24                http://hawaii.gov/dot/airports/hnl/
# 25                      http://www.mwaa.com/national/
# 26  http://www.flychicago.com/midway/MidwayHomepag...
# 27                                http://www.san.org/
# 28                                                NaN
# 29                                                NaN
# 30                    http://www.lambert-stlouis.com/
# 31                                                NaN
# 32                                                NaN
# 33                   http://www.clevelandairport.com/
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39               http://www.fly2houston.com/hobbyHome
# 40                              http://www.ocair.com/
# 41          http://www.ci.austin.tx.us/austinairport/
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                        wikipedia_link  \
# 0   http://en.wikipedia.org/wiki/Hartsfield-Jackso...
# 1   http://en.wikipedia.org/wiki/O'Hare_Internatio...
# 2   http://en.wikipedia.org/wiki/Los_Angeles_Inter...
# 3   http://en.wikipedia.org/wiki/Dallas-Fort_Worth...
# 4   http://en.wikipedia.org/wiki/Denver_Internatio...
# 5   http://en.wikipedia.org/wiki/John_F._Kennedy_I...
# 6   http://en.wikipedia.org/wiki/San_Francisco_Int...
# 7   http://en.wikipedia.org/wiki/George_Bush_Inter...
# 8   http://en.wikipedia.org/wiki/McCarran_Internat...
# 9   http://en.wikipedia.org/wiki/Phoenix_Sky_Harbo...
# 10  http://en.wikipedia.org/wiki/Charlotte/Douglas...
# 11  http://en.wikipedia.org/wiki/Miami_Internation...
# 12  http://en.wikipedia.org/wiki/Orlando_Internati...
# 13  http://en.wikipedia.org/wiki/Newark_Liberty_In...
# 14  http://en.wikipedia.org/wiki/Detroit_Metropoli...
# 15  http://en.wikipedia.org/wiki/Minneapolis-Saint...
# 16  http://en.wikipedia.org/wiki/Seattle-Tacoma_In...
# 17  http://en.wikipedia.org/wiki/Philadelphia_Inte...
# 18  http://en.wikipedia.org/wiki/Logan_Internation...
# 19     http://en.wikipedia.org/wiki/LaGuardia_Airport
# 20  http://en.wikipedia.org/wiki/Washington_Dulles...
# 21  http://en.wikipedia.org/wiki/Baltimore-Washing...
# 22  http://en.wikipedia.org/wiki/Fort_Lauderdale-H...
# 23  http://en.wikipedia.org/wiki/Salt_Lake_City_In...
# 24  http://en.wikipedia.org/wiki/Honolulu_Internat...
# 25  http://en.wikipedia.org/wiki/Ronald_Reagan_Was...
# 26  http://en.wikipedia.org/wiki/Chicago_Midway_In...
# 27  http://en.wikipedia.org/wiki/San_Diego_Interna...
# 28  http://en.wikipedia.org/wiki/Tampa_Internation...
# 29  http://en.wikipedia.org/wiki/Portland_Internat...
# 30  http://en.wikipedia.org/wiki/Lambert-St._Louis...
# 31                                                NaN
# 32  http://en.wikipedia.org/wiki/Memphis_Internati...
# 33  http://en.wikipedia.org/wiki/Cleveland_Hopkins...
# 34  http://en.wikipedia.org/wiki/Oakland_Internati...
# 35  http://en.wikipedia.org/wiki/Luis_Mu%C3%B1oz_M...
# 36  http://en.wikipedia.org/wiki/Raleigh-Durham_In...
# 37  http://en.wikipedia.org/wiki/Nashville_Interna...
# 38  http://en.wikipedia.org/wiki/Sacramento_Intern...
# 39  http://en.wikipedia.org/wiki/William_P._Hobby_...
# 40    http://en.wikipedia.org/wiki/John_Wayne_Airport
# 41  http://en.wikipedia.org/wiki/Austin-Bergstrom_...
# 42  http://en.wikipedia.org/wiki/San_Jose_Internat...
# 43  http://en.wikipedia.org/wiki/Louis_Armstrong_N...
# 44  http://en.wikipedia.org/wiki/Pittsburgh_Intern...
# 45  http://en.wikipedia.org/wiki/San_Antonio_Inter...
# 46  http://en.wikipedia.org/wiki/Cincinnati/Northe...
# 47  http://en.wikipedia.org/wiki/General_Mitchell_...
# 48     http://en.wikipedia.org/wiki/Dallas_Love_Field
# 49  http://en.wikipedia.org/wiki/Indianapolis_Inte...
#
#                                              keywords
# 0                                                 NaN
# 1                                  CHI, Orchard Place
# 2                                                 NaN
# 3                                                 QDF
# 4                                                 NaN
# 5             Manhattan, New York City, NYC, Idlewild
# 6                                            QSF, QBA
# 7                                                 QHO
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                 MFW, South Florida
# 12                          Disney World,Epcot Center
# 13                      Manhattan, New York City, NYC
# 14                         DTT, Detroit Metro Airport
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  General Edward Lawrence Logan International Ai...
# 19  Manhattan, New York City, NYC, Glenn H. Curtis...
# 20                                                WAS
# 21                                                WAS
# 22                                 MFW, South Florida
# 23                                                NaN
# 24             Hickam Air Force Base, HIK, PHIK, KHNL
# 25                                                WAS
# 26                                                CHI
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                           QSF, QBA
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                QHO
# 40                  Disney, Disneyland, Orange County
# 41                                                NaN
# 42                                           QSF, QBA
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                QDF
# 49                                                NaN

# %%
#Make AirportData.db database, make AirportData table, and fill it with the airport data.
import sqlite3
# sql_cmd = """CREATE TABLE AirportData (id INTEGER PRIMARY KEY AUTOINCREMENT,
#     code TEXT, latitude FLOAT, longitude FLOAT, elevation FLOAT, 
#     network TEXT, status TEXT, name TEXT)"""
connection = sqlite3.connect('AirportData.db')
cursor = connection.cursor()
sql_cmd = """CREATE TABLE AirportData (id INTEGER PRIMARY KEY AUTOINCREMENT,
    City TEXT, Airport TEXT, ICAO TEXT, Longitude FLOAT, Latitude FLOAT, Elevation FLOAT)"""
cursor.execute(sql_cmd)
count = 0
for y in airdata:
    airport_city = str(airdata['City'])
    airport_name = str(airdata['name'])
    airport_ICAO = str(airdata['ICAO'])
    airport_long = str(airdata['longitude_deg'])
    airport_lat = str(airdata['latitude_deg'])
    airport_elev = str(airdata['elevation_ft'])
    data = (airport_city, airport_name, airport_ICAO, airport_long, airport_lat, airport_elev)
    sql_cmd = ("INSERT INTO AirportData (City, Airport, ICAO, Longitude, Latitude, Elevation) VALUES " + str(data))
    cursor.execute(sql_cmd)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-10-03e75ce3532f> in <module>()
#       8 sql_cmd = """CREATE TABLE AirportData (id INTEGER PRIMARY KEY AUTOINCREMENT,
#       9     City TEXT, Airport TEXT, ICAO TEXT, Longitude FLOAT, Latitude FLOAT, Elevation FLOAT)"""
# ---> 10 cursor.execute(sql_cmd)
#      11 count = 0
#      12 for y in airdata:
#
# OperationalError: table AirportData already exists

# %% [markdown]
# #### Okay, but this is a database practice, so let's do this in the database

# %%
# read in the airport data and the list of top airports 
airport_data = pd.read_csv('ICAO_airports.csv')
top_airports = pd.read_csv('top_airports.csv')

# %%
connection = sqlite3.connect('AirportDataBase.db')
cursor = connection.cursor()
sql_cmd = """CREATE TABLE AirportData (pk INTEGER PRIMARY KEY AUTOINCREMENT,
    tid TEXT, ident TEXT, atype TEXT, name TEXT, latitude FLOAT, longitude FLOAT, elevation TEXT,
    continent TEXT, iso_country TEXT, iso_region TEXT, municipality TEXT, service_sched TEXT,
    gps_code TEXT, iata_code TEXT, local_code TEXT, home_link TEXT, wiki_link TEXT, key_words TEXT)"""
cursor.execute(sql_cmd)

for row in range(airport_data.shape[0]):
#for row in range(10):
    Vid1 = airport_data.loc[row]['id']; Vthe_type = airport_data.loc[row]['type'] 
    Vident = airport_data.loc[row]['ident'];  Vname = airport_data.loc[row]['name']
    Vlat = airport_data.loc[row]['latitude_deg'];  Vlon = airport_data.loc[row]['longitude_deg']  
    Vele = airport_data.loc[row]['elevation_ft'];  Vcont = airport_data.loc[row]['continent']  
    Vicoc = airport_data.loc[row]['iso_country'];  Visor = airport_data.loc[row]['iso_region']  
    Vmuni = airport_data.loc[row]['municipality'];  Vsched = airport_data.loc[row]['scheduled_service']      
    Vgps = airport_data.loc[row]['gps_code'];  Viata = airport_data.loc[row]['iata_code']
    Vlocal = airport_data.loc[row]['local_code'];  Vhlink = airport_data.loc[row]['home_link']
    Vwlink = airport_data.loc[row]['wikipedia_link'];  Vkwords = airport_data.loc[row]['keywords']    
    
    data = (str(Vid1),Vident,Vthe_type,Vname,Vlat,Vlon,str(Vele),
            str(Vcont),str(Vicoc),Visor,str(Vmuni),Vsched,
            str(Vgps),str(Viata),str(Vlocal),
            str(Vhlink),str(Vwlink),str(Vkwords))
    
    sql_cmd = ("INSERT INTO AirportData (tid, ident, atype, name, latitude, longitude, elevation," +  
     "continent, iso_country, iso_region, municipality, service_sched, gps_code, iata_code," +  
     "local_code, home_link, wiki_link, key_words) VALUES " + str(data))
    cursor.execute(sql_cmd)
    connection.commit()

connection.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-12-41c1aa6743de> in <module>()
#       5     continent TEXT, iso_country TEXT, iso_region TEXT, municipality TEXT, service_sched TEXT,
#       6     gps_code TEXT, iata_code TEXT, local_code TEXT, home_link TEXT, wiki_link TEXT, key_words TEXT)"""
# ----> 7 cursor.execute(sql_cmd)
#       8
#       9 for row in range(airport_data.shape[0]):
#
# OperationalError: table AirportData already exists

# %%
import csv
connection = sqlite3.connect('AirportDataBase.db') # after a long time realized the deal is you have multiple TABLES in a single .DB
cursor = connection.cursor()
sql_cmd = """CREATE TABLE TopAirports (pk INTEGER PRIMARY KEY AUTOINCREMENT,
    city TEXT, FAA TEXT, IATA TEXT, ICAO TEXT, name TEXT, role TEXT, enplanements FLOAT)
   """
cursor.execute(sql_cmd)

with open('top_airports.csv','rb') as TAP: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(TAP) # comma is default delimiter
    to_db = [(unicode(r['City'],"utf8"), unicode(r['FAA'],"utf8"), 
            unicode(r['IATA'],"utf8"), unicode(r['ICAO'],"utf8"), 
            unicode(r['Airport'],"utf8"), unicode(r['Role'],"utf8"), 
            unicode(r['Enplanements'],"utf8")) for r in dr]

cursor.executemany("INSERT INTO TopAirports (city,FAA,IATA,ICAO,name,role,enplanements) VALUES (?, ?, ?, ?, ?, ?, ?);", to_db)
connection.commit()
connection.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-9f2ecc2bd5ce> in <module>()
#       5     city TEXT, FAA TEXT, IATA TEXT, ICAO TEXT, name TEXT, role TEXT, enplanements FLOAT)
#       6    """
# ----> 7 cursor.execute(sql_cmd)
#       8
#       9 with open('top_airports.csv','rb') as TAP: # `with` statement available in 2.5+
#
# OperationalError: table TopAirports already exists

# %%
# create the db we'll be entering our joined data into
connection = sqlite3.connect('AirportDataBase.db')
cursor = connection.cursor()
sql_cmd = """CREATE TABLE TopAirportsData (pk INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT, city TEXT, icao TEXT, latitude FLOAT, longitude FLOAT, elevation FLOAT)"""
cursor.execute(sql_cmd)

# get the data that's in both tables.  the IATA code should be 
# unique in both tables
sql_cmd = """SELECT TopAirports.name, TopAirports.city,
    TopAirports.ICAO, AirportData.latitude, AirportData.longitude, 
    AirPortData.elevation FROM TopAirports, AirportData WHERE 
    TopAirports.IATA = AirportData.iata_code"""
cursor.execute(sql_cmd)

db_info = cursor.fetchall()
for entry in db_info: 
    to_db = (entry[0].encode('utf-8'), entry[1].encode('utf-8'), 
             entry[2].encode('utf-8'), entry[3],entry[4], entry[5].encode('utf-8'))
    sql_cmd = ("INSERT INTO TopAirportsData (name,city,icao,latitude,longitude,elevation) VALUES " + str(to_db))
    cursor.execute(sql_cmd)
    connection.commit()
    
connection.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-14-041fcb411885> in <module>()
#       4 sql_cmd = """CREATE TABLE TopAirportsData (pk INTEGER PRIMARY KEY AUTOINCREMENT,
#       5     name TEXT, city TEXT, icao TEXT, latitude FLOAT, longitude FLOAT, elevation FLOAT)"""
# ----> 6 cursor.execute(sql_cmd)
#       7
#       8 # get the data that's in both tables.  the IATA code should be
#
# OperationalError: table TopAirportsData already exists

# %% [markdown]
# #### All of thouse should have errored with OperationalError

# %% [markdown]
# #### Part 2: Build another table that will hold historical weather information, such as min/max temperature, humidity, precipitation, and cloud cover.

# %%
#Will create this on the fly!

# %% [markdown]
# #### Part 3: Grab historical data from weather underground from 2008 until now and populate your tables accordingly
# HINT: You can access a month’s worth of tabular weather data in CSV format from Weather Underground using the ICAO airport code. For instance, to get the weather for San Francisco airport (ICAO code KSFO) in the month of September 2013, go to:
# http://www.wunderground.com/history/airport/KSFO/2013/9/1/MonthlyHistory.html?format=1

# %% [markdown]
# ### DON'T RUN ANY OF THIS!

# %%
import urllib2
from cStringIO import StringIO
ICAO = 'KORD'
year = 2008
month = 1
data = urllib2.urlopen('/'.join(['http://www.wunderground.com/history/airport',
        ICAO, str(year), str(month), '1/MonthlyHistory.html?format=1'])).read().replace('<br />', '')

# %%
# get the list of airports via their ICAO code
sql_cmd = 'SELECT TopAirports.ICAO from TopAirports'
connection = sqlite3.connect('AirportDataBase.db')
cursor = connection.cursor()
cursor.execute(sql_cmd)
db_info = cursor.fetchall()

for airport in db_info:
    sql_cmd = ("CREATE TABLE " + str(airport[0]) + "_WeatherData " + 
    "(pk INTEGER PRIMARY KEY AUTOINCREMENT, date DATE, name TEXT, city TEXT, " + 
    "icao TEXT, latitude FLOAT, longitude FLOAT, elevation FLOAT, " +
    "min_temp FLOAT, max_temp FLOAT, mean_temp FLOAT, mean_humidity FLOAT, " + 
    "mean_pressure FLOAT,wind_speed FLOAT, cloud_cover FLOAT, precipitation TEXT)")
    
    cursor.execute(sql_cmd)

# %%
# now grab the weather data form the web for each of these airports
# and populate the appropriate table (getting the sneaking suspicion here that
# creation, data gathering, and table population should have all been done 
# in one step but what'yre gonna do?)
missingval = 0
for airport in db_info:
    ICAO = str(airport[0])
    # get non-weather data from other tables
    sql_cmd = ('SELECT TopAirportsData.name, TopAirportsData.city, ' + 
    'TopAirportsData.latitude, TopAirportsData.longitude, ' + 
    'TopAirportsData.elevation from TopAirportsData WHERE ' + 
    'TopAirportsData.icao = \'' + ICAO + '\'')
    cursor.execute(sql_cmd)
    ap_info = cursor.fetchall()
    
    # this is insane
    Name = ap_info[0][0].encode('utf-8')
    City = ap_info[0][1].encode('utf-8')
    Lat = ap_info[0][2]
    Lon = ap_info[0][3]
    Ele = ap_info[0][4]
    
    # ok, populate the tables with data
    for year in xrange(2008, 2014):
        if year == 2013:
            monthrange = xrange(1,11)
        else:
            monthrange = xrange(1,13)
            for month in monthrange:
                # Remove '<br />' HTML crud at the end of each line.
                x = True
                while x == True: 
                    try: 
                        data = urllib2.urlopen('/'.join(['http://www.wunderground.com/history/airport', 
                        ICAO, str(year), str(month), '1/MonthlyHistory.html?format=1'])).read().replace('<br />', '')
                        x = False
                    except URLError:
                        time.sleep(1)
                # now data is the long string from the website.  break it up at the /ns
                days = data.split('\n')
                days = days[2:] #first row is headers and second is nothing
                
                for day in days:
                    the_data = days[0].split(',')
                    
                    Date = the_data[0]
                    try:
                        MinTemp = float(the_data[3])
                        MaxTemp = float(the_data[1])
                        MeanTemp = float(the_data[2])
                        MeanHumid = float(the_data[8])
                        MeanPres = float(the_data[11])
                        WindSpeed = float(the_data[17])
                        CloudCover = float(the_data[20])
                        Precip = the_data[19]
                    except ValueError:
                        missingval =+1 
                    
                    # great, now just add it to the table
                    to_db = [(Date, Name, City, ICAO, Lat, Lon, Ele, 
                    MinTemp, MaxTemp, MeanTemp, MeanHumid, MeanPres, WindSpeed, 
                    CloudCover, Precip.encode('utf-8'))]
                    
                    cursor.executemany('INSERT INTO ' + ICAO + '_WeatherData ' +
                    '(date,name,city,icao,latitude,longitude,elevation,' + 
                    'min_temp,max_temp,mean_temp,mean_humidity,mean_pressure,' + 
                    'wind_speed,cloud_cover,precipitation) ' + 
                    'VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)' + 
                    ';', to_db)
                    connection.commit()

# %% [markdown]
# ### RUN THIS

# %%
import pickle
# dbinfo = open('db_info.txt', 'w')
# pickle.dump(db_info, dbinfo)
# dbinfo.close()
info = open('db_info.txt', 'r')
listofairports = pickle.load(info)
listofairports
db_info = listofairports

# %% [markdown]
# #### Part 4 For each pair of cities/airports determine how the daily change of high temperature and cloud cover from one city predicts the daily change of the other city 1,3, & 7 days in advance
# NOTE: Cloud cover from the Weather Underground tables ranges from 0 (clear) to 8 (completely cloudy)

# %%
nports = 50
ndpoints = 1887 # hard code for now

## initialize two arrays
airportTemps = np.zeros((ndpoints,nports))
airportClouds = np.zeros((ndpoints,nports))

for col, airport in enumerate(db_info):
    ICAO = str(airport[0])

    # get non-weather data from other tables
    sql_cmd = ('SELECT ' + ICAO + '_WeatherData.max_temp, ' + 
    ICAO + '_WeatherData.cloud_cover from ' + ICAO + '_WeatherData')

    cursor.execute(sql_cmd)
    vectors = cursor.fetchall()
    vectors = np.asarray(vectors)
    temps = vectors[:,0]
    humidities = vectors[:,1] # the above three lines could be condensed but i don't care
    
    # store in array
    airportTemps[:,col] = temps[:1887]
    airportClouds[:,col] = humidities[:1887]

# %%
# initialize arrays
TempCors = np.zeros((nports,nports,3)) # lags to be stacked in 3rd dim
CloudCors = np.zeros((nports,nports,3))

# list the lag in days
lags = [1,2,6] 

for a1 in range(nports):
    tempSeed = airportTemps[:,a1]
    CloudSeed = airportClouds[:,a1]
    
    for a2 in range(nports):
        tempTarg = airportTemps[:,a2]
        CloudTarg = airportClouds[:,a2]
        
        for page,lag in enumerate(lags):

            # lag the target airport by
            # the correct number of days
            LaggedTempTarg = tempTarg[lag:]
            LaggedCloudTarg = CloudTarg[lag:]
                
            # remove the correct number of 
            # days from the end of the 
            # seed timeseries
            LaggedTempSeed = tempSeed[:-lag]
            LaggedCloudSeed = CloudSeed[:-lag]
               
            # get corr and store in the big arrays
            tmp = np.corrcoef(LaggedTempTarg,LaggedTempSeed)
            TempCors[a1,a2,page] = tmp[0,1] # any off diagnoal
            tmp = np.corrcoef(LaggedCloudTarg,LaggedCloudSeed)                
            CloudCors[a1,a2,page] = tmp[0,1]

# %% [markdown]
# #### Part 5 Plot the correlation strengths for the 10 top pairs for all three dates, for both temperature and cloud cover as a function of distance. Also make a plot as a function of longitude difference. What trends do you see?

# %% [markdown]
# #### Check out a good looking matrix to make sure the data is real

# %%
from pylab import pcolor, show, colorbar, imshow
imshow(CloudCors[:,:,0])
colorbar()
show()

# %%
def distance(point1,point2):
    # take two points, each (lat,lon)
    # and return euclidean distance
    point1 = np.asarray(point1)
    point2 = np.asarray(point2)
    diff = point1 - point2
    dist = np.sqrt(np.sum(diff**2))
    return dist

# %%
# initialize distance matrix
airportDistances = np.zeros((nports,nports))
airportLongitudes = np.zeros((nports,nports))

for a1,airport1 in enumerate(db_info): 
    IC1 = str(airport1[0])
    for a2,airport2 in enumerate(db_info):
        IC2 = str(airport2[0])

        sql_cmd = ('SELECT latitude, longitude FROM TopAirportsData ' + 'WHERE ICAO = \'' + str(IC1) + '\'')
        cursor.execute(sql_cmd)
        point1 = np.asarray(cursor.fetchall())
        
        sql_cmd = ('SELECT latitude, longitude FROM TopAirportsData ' + 'WHERE ICAO = \'' + str(IC2) + '\'')
        cursor.execute(sql_cmd)
        point2 = np.asarray(cursor.fetchall())        
        
        airportDistances[a1,a2] = distance(point1,point2)
        airportLongitudes[a1,a2] = point1[0][1]-point2[0][1]

# %%
#thanks to DAN BLISS
def top_ten(matrix):
    """Return indices for the ten elements of matrix, not along the diagonal, with the largest values.
    
    Parameters
    ----------
    matrix : numpy array
        Two-dimensional array.
    
    Returns
    -------
    indices : list of tuples
        List of (row, column) indicies of the ten largest values in matrix, in order from largest to smallest.
        
    values : list of floats
        The largest elements in matrix, in order from largest to smallest.

    """
    x, y = np.unravel_index(np.argsort(matrix, axis=None), matrix.shape)
    indices = zip(x, y)[::-1]
    indices = [(x, y) for x, y in indices if x != y][:10]
    values = [matrix[x, y] for x, y in indices]
    return indices, values

# %%
#made this to plot names but ran out of time, and amount of how much I cared.
namedict={}
for i, v in enumerate(db_info):
    namedict[i] = str(v[0])

# %%
# for each of the different lags, make list of correlations.
for i,l  in enumerate(lags):
    lg = str(l)
    
    # get the top ten cloud correlations at that lag and record the indexs (seedaiport, target airport)
    cmd = ('cloud_top' + lg + '_idx, cloud_top' + lg + '_vals = np.asarray(top_ten(CloudCors[:,:,i]))')
    exec(cmd)
    
    # repeat for temperatures 
    cmd = ('temp_top' + lg + '_idx, temp_top' + lg + '_vals = np.asarray(top_ten(TempCors[:,:,i]))')
    exec(cmd)
    
    # initialize empty lists of distances and longitudes
    exec('cloud_top' + lg + '_dist = []');exec('cloud_top' + lg + '_longs = []')
    exec('temp_top' + lg + '_dist = []');exec('temp_top' + lg + '_longs = []')
    
    # get the indexes for this metric
    exec('the_idxs = cloud_top' + lg + '_idx')
    # and get the distances between each of those airports
    for v in the_idxs:
        exec('cloud_top' + lg + '_dist.append(airportDistances[v])')
        exec('cloud_top' + lg + '_longs.append(airportDistances[v])')
        
    # repeat for temps    
    exec('the_idxs = temp_top' + lg + '_idx')   
    for v in the_idxs:
        exec('temp_top' + lg + '_dist.append(airportDistances[v])')
        exec('temp_top' + lg + '_longs.append(airportDistances[v])')


    # make into arrays for plotting    
    exec('cloud_top' + lg + '_dist = np.asarray(cloud_top' + lg + '_dist)')        
    exec('temp_top' + lg + '_dist = np.asarray(temp_top' + lg + '_dist)')            
    
    exec('cloud_top' + lg + '_longs = np.asarray(cloud_top' + lg + '_longs)')        
    exec('temp_top' + lg + '_longs = np.asarray(temp_top' + lg + '_longs)')

# %%
from matplotlib import pyplot as plt
f = plt.figure()
# Make the figure nice and big.
f.set_size_inches((20, 5))
ax = f.add_subplot(1, 2, 1)
ax.hold(True)
_ = ax.scatter(cloud_top1_dist, cloud_top1_vals, color='b', label='1 Day')
_ = ax.scatter(cloud_top2_dist, cloud_top2_vals, color='k', label='3 Days')
_ = ax.scatter(cloud_top6_dist, cloud_top6_vals, color='r', label='7 Days')
_ = ax.set_ylabel('Correlation Coefficient', size=13)
_ = ax.set_xlabel('Distance Between Airports ($^\circ$)', size=13)
_ = ax.legend()

ax = f.add_subplot(1, 2, 2)
ax.hold(True)
_ = ax.scatter(cloud_top1_longs, cloud_top1_vals, color='b', label='1 Day')
_ = ax.scatter(cloud_top2_longs, cloud_top2_vals, color='k', label='3 Days')
_ = ax.scatter(cloud_top6_longs, cloud_top6_vals, color='r', label='7 Days')
_ = ax.set_xlabel('Longitude Difference Between Airports ($^\circ$)', size=13)
xlim = ax.get_xlim()
_ = ax.set_xlim([0, xlim[1]])
_ = ax.legend()

title = f.suptitle('Inter-Airport Maximum Cloud Cover Correlations at Various\nTemporal Delays for the Ten Most Correlated Airports', size=15)
pos = title.get_position()
# Add some space between title and tops of plots.
_ = title.set_position((pos[0], pos[1] + 0.05))
plt.show()

# %% [markdown]
# #### Hmm looks exactly the same for both distances measures, and that distance does not matter that much for cloud cover, and it's more about days than distance

# %%
from matplotlib import pyplot as plt
f = plt.figure()
# Make the figure nice and big.
f.set_size_inches((20, 5))
ax = f.add_subplot(1, 2, 1)
ax.hold(True)
_ = ax.scatter(temp_top1_dist, temp_top1_vals, color='b', label='1 Day')
_ = ax.scatter(temp_top2_dist, temp_top2_vals, color='k', label='3 Days')
_ = ax.scatter(temp_top6_dist, temp_top6_vals, color='r', label='7 Days')
_ = ax.set_ylabel('Correlation Coefficient', size=13)
_ = ax.set_xlabel('Distance Between Airports ($^\circ$)', size=13)
# Distances can't be less than 0
xlim = ax.get_xlim()
_ = ax.set_xlim([0, xlim[1]])
_ = ax.legend()

ax = f.add_subplot(1, 2, 2)
ax.hold(True)
_ = ax.scatter(temp_top1_longs, temp_top1_vals, color='b', label='1 Day')
_ = ax.scatter(temp_top2_longs, temp_top2_vals, color='k', label='3 Days')
_ = ax.scatter(temp_top6_longs, temp_top6_vals, color='r', label='7 Days')
_ = ax.set_xlabel('Longitude Difference Between Airports ($^\circ$)', size=13)
xlim = ax.get_xlim()
_ = ax.set_xlim([0, xlim[1]])
_ = ax.legend()

title = f.suptitle('Inter-Airport Maximum Temperature Correlations at Various\nTemporal Delays for the Ten Most Correlated Airports', size=15)
pos = title.get_position()
# Add some space between title and tops of plots.
_ = title.set_position((pos[0], pos[1] + 0.05))
plt.show()

# %% [markdown]
# #### For this one it looks like day was still important, but distance was important as well
